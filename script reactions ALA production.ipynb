# %%
from cobra.io.dict import model_from_dict, model_to_dict
from cobra.io.json import from_json, load_json_model, save_json_model, to_json
from cobra.io.mat import load_matlab_model, save_matlab_model
from cobra.io.sbml import read_sbml_model, write_sbml_model, validate_sbml_model
from cobra.io.yaml import from_yaml, load_yaml_model, save_yaml_model, to_yaml
from cobra.io.web import AbstractModelRepository, BiGGModels, BioModels, load_model

# %%
from pathlib import Path
from cobra.io import load_json_model, save_json_model, load_matlab_model, save_matlab_model, read_sbml_model, write_sbml_model
import logging

data_dir = Path(".") / ".." / "src" / "cobra" / "data"
data_dir = data_dir.resolve()

print("mini test files: ")
print(", ".join(str(i) for i in data_dir.glob('mini*.*')))

textbook_model = load_model("textbook")
ecoli_model = load_model("iJO1366")
logging.getLogger("cobra.io.sbml").setLevel(logging.ERROR) # salmonella leads to lots of warnings without this line
# Out:
# mini test files:

# %% [markdown]
# IMPORT MODEL IN .json format

# %%
import cobra
from cobra import Reaction, Metabolite, Model
from cobra.util.solver import linear_reaction_coefficients
import cobra.test
from cobra.medium import minimal_medium
import os
import numpy as np
from os.path import join
import matplotlib.pyplot as plt

# **************MODEL LOADING SECTION*****************
# Loading the model
# Remember to edit the data_dir path to where the model is located (NOT including the name of the model itself in it
data_dir = r"C:\Users\santosm7\Documents"
# Check data_dir is as expected
print(data_dir + "\n")
# Load model; so join combines the path and model name for cobra's load method to function properly
import cobra
from cobra.io import load_json_model, save_json_model, load_matlab_model, save_matlab_model, read_sbml_model, write_sbml_model
model = cobra.io.load_json_model(join(data_dir, "iMS837-2022.json"))
print(f'{len(model.reactions)} reactions')
print(f'{len(model.metabolites)} metabolites')
print(f'{len(model.genes)} genes')
# Out:
# C:\Users\santosm7\Documents
#
# 887 reactions
# 801 metabolites
# 837 genes

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'h_c' )
m2 = model.metabolites.get_by_id( 'o2_c' ) 
m3 = model.metabolites.get_by_id( 'octe9ACP_c' ) 
m4 = model.metabolites.get_by_id( 'fdxrd_c' ) 
m5 = model.metabolites.get_by_id( 'h2o_c' ) 
m6 = Metabolite(
    'octe(9:12)ACP_c',
    formula='C29H51N2O8PRS',
    name='linoleoyl-ACP (n-C18:2ACP)',
    compartment='c')
m7 = model.metabolites.get_by_id( 'fdxox_c' ) 

from cobra import Reaction
#add DesA reaction:
reaction1 = Reaction( 'DES::12' )
reaction1.name = 'stearoyl-CoA desaturase (delta-12 desaturase)'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 2.0, m2: - 1.0, m3: - 1.0, m4: -2.0, m5: 2.0, m6: 1.0, m7: 2.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'h_c' )
m2 = model.metabolites.get_by_id( 'o2_c' ) 
m3 = model.metabolites.get_by_id( 'octe(9:12)ACP_c' ) 
m4 = model.metabolites.get_by_id( 'fdxrd_c' ) 
m5 = model.metabolites.get_by_id( 'h2o_c' ) 
m6 = Metabolite(
    'octe(9:12:15)ACP_c',
    formula='C29H49N2O8PRS',
    name='alpha-lineloyl-ACP (n-C18:3ACP)',
    compartment='c')
m7 = model.metabolites.get_by_id( 'fdxox_c' ) 

from cobra import Reaction
#add DesB reaction:
reaction1 = Reaction( 'DES::15' )
reaction1.name = 'stearoyl-CoA desaturase (delta-15 desaturase)'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 2.0, m2: - 1.0, m3: - 1.0, m4: -2.0, m5: 2.0, m6: 1.0, m7: 2.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = Metabolite(
    '1odec912eg3p_c',
    formula='C21H37O7P1',
    name='1-octadec-9-12-dienoyl-sn-glycerol 3-phosphate',
    compartment='c')
m2 = model.metabolites.get_by_id( 'octe(9:12)ACP_c' ) 
m3 = model.metabolites.get_by_id( 'ACP_c' ) 
m4 = Metabolite(
    'pa182:9:12_c',
    formula='C39H67O8P1',
    name='1,2-dioctadec-9-12-dienoyl-sn-glycerol 3-phosphate',
    compartment='c')

from cobra import Reaction
reaction1 = Reaction( 'AGPAT182(9:12)' )
reaction1.name = '1-octadec-enoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C18:2)'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: 1.0, m4: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'octe(9:12)ACP_c' ) 
m2 = Metabolite(
    '1odec91215eg3p_c',
    formula='C21H35O7P1',
    name='1-octadec-9-12-15-trienoyl-sn-glycerol 3-phosphate',
    compartment='c')
m3 = model.metabolites.get_by_id( 'ACP_c' ) 
m4 = Metabolite(
    'pa183:9:12:15_c',
    formula='C39H63O8P1',
    name='1,2-dioctadec-9-12-15-trienoyl-sn-glycerol 3-phosphate',
    compartment='c')

from cobra import Reaction
reaction1 = Reaction( 'AGPAT183(9:12:15)' )
reaction1.name = '1-octadec-enoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C18:3)'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: 1.0, m4: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'octe(9:12)ACP_c' ) 
m2 = model.metabolites.get_by_id( 'glyc3p_c' ) 
m3 = model.metabolites.get_by_id( 'ACP_c' ) 
m4 = model.metabolites.get_by_id( '1odec912eg3p_c' ) 

from cobra import Reaction
reaction1 = Reaction( 'G3PAT182(9:12)' )
reaction1.name = 'glycerol-3-phosphate acyltransferase (C18:2)'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: 1.0, m4: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'octe(9:12:15)ACP_c' ) 
m2 = model.metabolites.get_by_id( 'glyc3p_c' ) 
m3 = model.metabolites.get_by_id( 'ACP_c' ) 
m4 = model.metabolites.get_by_id( '1odec91215eg3p_c' ) 

from cobra import Reaction
reaction1 = Reaction( 'G3PAT183(9:12:15)' )
reaction1.name = 'glycerol-3-phosphate acyltransferase (C18:3)'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: 1.0, m4: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'h_c' ) 
m2 = model.metabolites.get_by_id( 'pa182:9:12_c' ) 
m3 = model.metabolites.get_by_id( 'ctp_c' ) 
m4 = model.metabolites.get_by_id( 'ppi_c' ) 
m5 = Metabolite(
    'cdpdodec912eg_c',
    formula='C48H79N3O15P2',
    name='CDP-1,2-dioctadec-9-12-dienoylglycerol',
    compartment='c')

from cobra import Reaction
reaction1 = Reaction( 'DASYN182(9:12)' )
reaction1.name = 'CDP-diacylglycerol synthetase (n-C18:2)'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: -1.0, m4: 1.0, m5: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'h_c' ) 
m2 = model.metabolites.get_by_id( 'pa183:9:12:15_c' ) 
m3 = model.metabolites.get_by_id( 'ctp_c' ) 
m4 = model.metabolites.get_by_id( 'ppi_c' ) 
m5 = Metabolite(
    'cdpdodec91215eg_c',
    formula='C48H75N3O15P2',
    name='CDP-1,2-dioctadec-9-12-15-trienoylglycerol',
    compartment='c')

from cobra import Reaction
reaction1 = Reaction( 'DASYN183(9:12:15)' )
reaction1.name = 'CDP-diacylglycerol synthetase (n-C18:3)'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: -1.0, m4: 1.0, m5: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'h2o_c' ) 
m2 = Metabolite(
    'pgp182:9:12_c',
    formula='C42H73O13P2',
    name='Phosphatidylglycerophosphate (dioctadec-9-12-dienoyl, n-C18:2)',
    compartment='c')
m3 = model.metabolites.get_by_id( 'pi_c' ) 
m4 = Metabolite(
    'pg182:9:12_c',
    formula='C42H74O10P1',
    name='Phosphatidylglycerol (dioctadec-9-12-dienoyl, n-C18:2)',
    compartment='c')

from cobra import Reaction
reaction1 = Reaction( 'PGPP182(9:12)' )
reaction1.name = 'phosphatidylglycerol phosphate phosphatase (n-C18:2)'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: 1.0, m4: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'h2o_c' ) 
m2 = Metabolite(
    'pgp183:9:12:15_c',
    formula='C42H69O13P2',
    name='Phosphatidylglycerophosphate (dioctadec-9-12-15-trienoyl, n-C18:3)',
    compartment='c')
m3 = model.metabolites.get_by_id( 'pi_c' ) 
m4 = Metabolite(
    'pg183:9:12:15_c',
    formula='C42H70O10P1',
    name='Phosphatidylglycerol (dioctadec-9-12-15-trienoyl, n-C18:3)',
    compartment='c')

from cobra import Reaction
reaction1 = Reaction( 'PGPP183(9:12:15)' )
reaction1.name = 'phosphatidylglycerol phosphate phosphatase (n-C18:3)'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: 1.0, m4: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'cdpdodec912eg_c' ) 
m2 = model.metabolites.get_by_id( 'glyc3p_c' )
m3 = model.metabolites.get_by_id( 'h_c' )
m4 = model.metabolites.get_by_id( 'cmp_c' ) 
m5 = model.metabolites.get_by_id( 'pgp182:9:12_c' ) 

from cobra import Reaction
reaction1 = Reaction( 'PGSA182(9:12)' )
reaction1.name = 'Phosphatidylglycerol synthase (n-C18:2)'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: 1.0, m4: 1.0, m5: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'cdpdodec91215eg_c' ) 
m2 = model.metabolites.get_by_id( 'glyc3p_c' )
m3 = model.metabolites.get_by_id( 'h_c' )
m4 = model.metabolites.get_by_id( 'cmp_c' ) 
m5 = model.metabolites.get_by_id( 'pgp183:9:12:15_c' ) 

from cobra import Reaction
reaction1 = Reaction( 'PGSA183(9:12:15)' )
reaction1.name = 'Phosphatidylglycerol synthase (n-C18:3)'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: 1.0, m4: 1.0, m5: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'udpgal_c' ) 
m2 = Metabolite(
    'mgdg182:9:12_c',
    formula='C45H74O5',
    name='1,2-Diacyl-3-beta-D-galactosyl-sn-glycerol (n-C18:2)',
    compartment='c')
m3 = model.metabolites.get_by_id( 'udp_c' )
m4 = Metabolite(
    'dgdg182:9:12_c',
    formula='C51H85O10',
    name='Digalactosyl-diacylglycerol(n-C18:2)',
    compartment='c')

from cobra import Reaction
reaction1 = Reaction( 'DGDG182(9:12)' )
reaction1.name = 'digalactosyldiacylglycerol synthase (n-C18:2)'
reaction1.subsystem = 'Galactolipids metabolism'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: 1.0, m4: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'udpgal_c' ) 
m2 = Metabolite(
    'mgdg183:9:12:15_c',
    formula='C45H70O5',
    name='1,2-Diacyl-3-beta-D-galactosyl-sn-glycerol (n-C18:3)',
    compartment='c')
m3 = model.metabolites.get_by_id( 'udp_c' )
m4 = Metabolite(
    'dgdg183:9:12:15_c',
    formula='C51H81O10',
    name='Digalactosyl-diacylglycerol(n-C18:2)',
    compartment='c')

from cobra import Reaction
reaction1 = Reaction( 'DGDG183(9:12:15)' )
reaction1.name = 'digalactosyldiacylglycerol synthase (n-C18:3)'
reaction1.subsystem = 'Galactolipids metabolism'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: 1.0, m4: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'udpgal_c' ) 
m2 = Metabolite(
    '12dgr182:9:12_c',
    formula='C39H68O5',
    name='1,2-Diacyl-sn-glycerol (dioctadec-9-12-dienoyl, n-C18:2)',
    compartment='c')
m3 = model.metabolites.get_by_id( 'h_c' )
m4 = model.metabolites.get_by_id( 'udp_c' )
m5 = Metabolite(
    'mgdg182:9:12_c',
    formula='C45H74O5',
    name='1,2-Diacyl-3-beta-D-galactosyl-sn-glycerol (n-C18:2)',
    compartment='c')

from cobra import Reaction
reaction1 = Reaction( 'MGDG182(9:12)' )
reaction1.name = 'UDPgalactose:1,2-diacylglycerol 3-beta-D-galactosyltransferase (n-C18:2)'
reaction1.subsystem = 'Galactolipids metabolism'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: 1.0, m4: 1.0, m5: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'udpgal_c' ) 
m2 = Metabolite(
    '12dgr183:9:12:15_c',
    formula='C39H64O5',
    name='1,2-Diacyl-sn-glycerol (dioctadec-9-12-15-trienoyl, n-C18:3)',
    compartment='c')
m3 = model.metabolites.get_by_id( 'h_c' )
m4 = model.metabolites.get_by_id( 'udp_c' )
m5 = Metabolite(
    'mgdg183:9:12:15_c',
    formula='C45H70O5',
    name='1,2-Diacyl-3-beta-D-galactosyl-sn-glycerol (n-C18:3)',
    compartment='c')

from cobra import Reaction
reaction1 = Reaction( 'MGDG183(9:12:15)' )
reaction1.name = 'UDPgalactose:1,2-diacylglycerol 3-beta-D-galactosyltransferase (n-C18:3)'
reaction1.subsystem = 'Galactolipids metabolism'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: 1.0, m4: 1.0, m5: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'h2o_c' ) 
m2 = model.metabolites.get_by_id( 'pa182:9:12_c' ) 
m3 = model.metabolites.get_by_id( 'pi_c' )
m4 = model.metabolites.get_by_id( '12dgr182:9:12_c' )

from cobra import Reaction
reaction1 = Reaction( 'PAPA182(9:12)' )
reaction1.name = 'Phosphatidate phosphatase (n-C18:2)'
reaction1.subsystem = 'Galactolipids metabolism'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: 1.0, m4: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'h2o_c' ) 
m2 = model.metabolites.get_by_id( 'pa183:9:12:15_c' ) 
m3 = model.metabolites.get_by_id( 'pi_c' )
m4 = model.metabolites.get_by_id( '12dgr183:9:12:15_c' )

from cobra import Reaction
reaction1 = Reaction( 'PAPA183(9:12:15)' )
reaction1.name = 'Phosphatidate phosphatase (n-C18:3)'
reaction1.subsystem = 'Galactolipids metabolism'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: 1.0, m4: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'h2o_c' ) 
m2 = model.metabolites.get_by_id( '12dgr182:9:12_c' ) 
m3 = model.metabolites.get_by_id( 'udpsq_c' )
m4 = model.metabolites.get_by_id( 'h_c' )
m5 = model.metabolites.get_by_id( 'udp_c' )
m6 = Metabolite(
    'sqdg182:9:12_c',
    formula='C45H75O13S',
    name='Sulfoquinovosyldiacylglycerol (n-C18:2)',
    compartment='c')

from cobra import Reaction
reaction1 = Reaction( 'SQD2_182:9:12' )
reaction1.name = 'sulfoquinovosyltransferase  (n-C18:2)'
reaction1.subsystem = 'Sulfolipid Biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: -1.0, m4: 1.0, m5: 1.0, m6: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'h2o_c' ) 
m2 = model.metabolites.get_by_id( '12dgr183:9:12:15_c' ) 
m3 = model.metabolites.get_by_id( 'udpsq_c' )
m4 = model.metabolites.get_by_id( 'h_c' )
m5 = model.metabolites.get_by_id( 'udp_c' )
m6 = Metabolite(
    'sqdg183:9:12:15_c',
    formula='C45H71O13S',
    name='Sulfoquinovosyldiacylglycerol (n-C18:3)',
    compartment='c')

from cobra import Reaction
reaction1 = Reaction( 'SQD2_183:9:12:15' )
reaction1.name = 'sulfoquinovosyltransferase  (n-C18:3)'
reaction1.subsystem = 'Sulfolipid Biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: - 1.0, m3: -1.0, m4: 1.0, m5: 1.0, m6: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'octe(9:12)ACP_c' ) 
m2 = model.metabolites.get_by_id( 'h2o_c' ) 
m3 = model.metabolites.get_by_id( 'ACP_c' ) 
m4 = Metabolite(
    'octe(9:12)_c',
    formula='C29H50N2O8P',
    name='linoleoate (n-C18:2)',
    compartment='c')
m5 = model.metabolites.get_by_id( 'h_c' )

from cobra import Reaction
reaction1 = Reaction( 'FA182ACPHi' )
reaction1.name = 'fatty acyl ACP hydrolase'
reaction1.subsystem = 'Fatty Acid Biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: -1.0, m3: 1.0, m4: 1.0, m5: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'octe(9:12:15)ACP_c' ) 
m2 = model.metabolites.get_by_id( 'h2o_c' ) 
m3 = model.metabolites.get_by_id( 'ACP_c' ) 
m4 = Metabolite(
    'octe(9:12:15)_c',
    formula='C29H48N2O8P',
    name='α-lineloyl (n-C18:3)',
    compartment='c')
m5 = model.metabolites.get_by_id( 'h_c' )

from cobra import Reaction
reaction1 = Reaction( 'FA183ACPHi' )
reaction1.name = 'fatty acyl ACP hydrolase'
reaction1.subsystem = 'Fatty Acid Biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: -1.0, m3: 1.0, m4: 1.0, m5: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'atp_c' ) 
m2 = model.metabolites.get_by_id( 'coa_c' ) 
m3 = model.metabolites.get_by_id( 'octe(9:12)_c' ) 
m4 = model.metabolites.get_by_id( 'amp_c' ) 
m5 = Metabolite(
    'octe(9:12)coa_c',
    formula='C39H62N7O17P3S',
    name='linoleic_coenzyme_A',
    compartment='c')
m4 = model.metabolites.get_by_id( 'ppi_c' ) 

from cobra import Reaction
reaction1 = Reaction( 'FACOAL1821i' )
reaction1.name = 'fatty acid CoA ligase'
reaction1.subsystem = 'Fatty Acid Metabolism'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: -1.0, m3: -1.0, m4: 1.0, m5: 1.0, m6: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'atp_c' ) 
m2 = model.metabolites.get_by_id( 'coa_c' ) 
m3 = model.metabolites.get_by_id( 'octe(9:12:15)_c' ) 
m4 = model.metabolites.get_by_id( 'amp_c' ) 
m5 = Metabolite(
    'octe(9:12:15)coa_c',
    formula='C39H60N7O17P3S',
    name='linolenic_coenzyme_A',
    compartment='c')
m4 = model.metabolites.get_by_id( 'ppi_c' ) 

from cobra import Reaction
reaction1 = Reaction( 'FACOAL1831i' )
reaction1.name = 'fatty acid CoA ligase'
reaction1.subsystem = 'Fatty Acid Metabolism'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: -1.0, m3: -1.0, m4: 1.0, m5: 1.0, m6: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'octe(9:12)coa_c' ) 
m2 = model.metabolites.get_by_id( 'h2o_c' ) 
m3 = model.metabolites.get_by_id( 'coa_c' )
m4 = model.metabolites.get_by_id( 'octe(9:12)_c' ) 
m5 = model.metabolites.get_by_id( 'h_c' ) 

from cobra import Reaction
#add FACOAE181 reaction:
reaction1 = Reaction( 'FACOAE182' )
reaction1.name = 'fatty acid CoA thioesterase linoleic acid'
reaction1.subsystem = 'Fatty Acid Metabolism'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: -1.0, m3: 1.0, m4: 1.0, m5: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'octe(9:12:15)coa_c' ) 
m2 = model.metabolites.get_by_id( 'h2o_c' ) 
m3 = model.metabolites.get_by_id( 'coa_c' )
m4 = model.metabolites.get_by_id( 'octe(9:12:15)_c' ) 
m5 = model.metabolites.get_by_id( 'h_c' ) 

from cobra import Reaction
#add FACOAE181 reaction:
reaction1 = Reaction( 'FACOAE1832' )
reaction1.name = 'fatty acid CoA thioesterase linolenic acid'
reaction1.subsystem = 'Fatty Acid Metabolism'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: -1.0, m3: 1.0, m4: 1.0, m5: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'octe9_c' ) 

from cobra import Reaction
reaction1 = Reaction( 'DM_OA' )
reaction1.name = 'Demand reaction OA'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'octe(9:12:15)_c' ) 

from cobra import Reaction
reaction1 = Reaction( 'DM_ALA' )
reaction1.name = 'Demand reaction ALA'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = Metabolite(
    'octe9_e',
    formula='C18H32O',
    name='Oleoyl',
    compartment='e')

from cobra import Reaction
reaction1 = Reaction( 'EX_OA(e)' )
reaction1.name = 'EX OA ext'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = Metabolite(
    'octe(9:12:15)_e',
    formula='C29H48N2O8P',
    name='α-lineloyl (n-C18:3)',
    compartment='e') 

from cobra import Reaction
reaction1 = Reaction( 'EX_ALA(e)' )
reaction1.name = 'EX ALA ext'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = 0
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'octe9_c' ) 
m2 = Metabolite(
    'octe9_p',
    formula='C18H32O',
    name='Oleoyl',
    compartment='p')

from cobra import Reaction
reaction1 = Reaction( 'OAtex1' )
reaction1.name = 'OA transport periplasm'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = -1000
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'octe9_p' ) 
m2 = model.metabolites.get_by_id( 'octe9_e' ) 

from cobra import Reaction
reaction1 = Reaction( 'OAtex2' )
reaction1.name = 'OA transport extracellular'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = -1000
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'octe(9:12:15)_c' ) 
m2 = Metabolite(
    'octe(9:12:15)_p',
    formula='C29H48N2O8P',
    name='α-lineloyl (n-C18:3)',
    compartment='p') 

from cobra import Reaction
reaction1 = Reaction( 'ALAtex1' )
reaction1.name = 'ALA transport periplasm'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = -1000
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: 1.0})
model.add_reaction(reaction1)

# %%
from cobra import Metabolite
m1 = model.metabolites.get_by_id( 'octe(9:12:15)_p' ) 
m2 = model.metabolites.get_by_id( 'octe(9:12:15)_e' ) 

from cobra import Reaction
reaction1 = Reaction( 'ALAtex2' )
reaction1.name = 'ALA transport extracellular'
reaction1.subsystem = 'Fatty acid biosynthesis'
reaction1.lower_bound = -1000
reaction1.upper_bound = 1000
reaction1.add_metabolites({m1: - 1.0, m2: 1.0})
model.add_reaction(reaction1)

# %%
print(f'{len(model.reactions)} reactions')
print(f'{len(model.metabolites)} metabolites')
print(f'{len(model.genes)} genes')
# Out:
# 921 reactions
# 829 metabolites
# 837 genes

# %%
cobra.io.save_json_model(model, "iMS837_ALA.json")

# %%
cobra.io.save_matlab_model(model, "iMS837_ALA.mat")
